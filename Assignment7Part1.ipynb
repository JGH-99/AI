# %% [markdown]
# <a href="https://colab.research.google.com/github/JGH-99/AI/blob/main/Assignment7Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")
    
import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)
    
import network2
net=network2.Network([784,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in 35.51
# Accuracy on evaluation data: 9015 / 10000
# Epoch 1 training complete in 35.74
# Accuracy on evaluation data: 9214 / 10000
# Epoch 2 training complete in 35.73
# Accuracy on evaluation data: 9358 / 10000
# Epoch 3 training complete in 35.32
# Accuracy on evaluation data: 9420 / 10000
# Epoch 4 training complete in 35.73
# Accuracy on evaluation data: 9447 / 10000
# Epoch 5 training complete in 36.02
# Accuracy on evaluation data: 9485 / 10000
# Epoch 6 training complete in 35.89
# Accuracy on evaluation data: 9543 / 10000
# Epoch 7 training complete in 35.07
# Accuracy on evaluation data: 9556 / 10000
# Epoch 8 training complete in 34.99
# Accuracy on evaluation data: 9581 / 10000
# Epoch 9 training complete in 35.22
# Accuracy on evaluation data: 9591 / 10000
# Epoch 10 training complete in 35.02
# Accuracy on evaluation data: 9619 / 10000
# Epoch 11 training complete in 34.86
# Accuracy on evaluation data: 9637 / 10000
# Epoch 12 training complete in 34.79
# Accuracy on evaluation data: 9631 / 10000
# Epoch 13 training complete in 34.89
# Accuracy on evaluation data: 9642 / 10000
# Epoch 14 training complete in 34.75
# Accuracy on evaluation data: 9655 / 10000
# Epoch 15 training complete in 34.56
# Accuracy on evaluation data: 9675 / 10000
# Epoch 16 training complete in 34.60
# Accuracy on evaluation data: 9682 / 10000
# Epoch 17 training complete in 34.72
# Accuracy on evaluation data: 9686 / 10000
# Epoch 18 training complete in 34.70
# Accuracy on evaluation data: 9686 / 10000
# Epoch 19 training complete in 34.52
# Accuracy on evaluation data: 9703 / 10000
# Epoch 20 training complete in 34.59
# Accuracy on evaluation data: 9687 / 10000
# Epoch 21 training complete in 34.52
# Accuracy on evaluation data: 9722 / 10000
# Epoch 22 training complete in 34.84
# Accuracy on evaluation data: 9719 / 10000
# Epoch 23 training complete in 34.71
# Accuracy on evaluation data: 9706 / 10000
# Epoch 24 training complete in 34.74
# Accuracy on evaluation data: 9727 / 10000
# Epoch 25 training complete in 34.90
# Accuracy on evaluation data: 9740 / 10000
# Epoch 26 training complete in 34.61
# Accuracy on evaluation data: 9730 / 10000
# Epoch 27 training complete in 34.69
# Accuracy on evaluation data: 9748 / 10000
# Epoch 28 training complete in 34.55
# Accuracy on evaluation data: 9737 / 10000
# Epoch 29 training complete in 34.46
# Accuracy on evaluation data: 9740 / 10000
# Epoch 30 training complete in 34.59
# Accuracy on evaluation data: 9746 / 10000
# Epoch 31 training complete in 34.72
# Accuracy on evaluation data: 9761 / 10000
# Epoch 32 training complete in 34.51
# Accuracy on evaluation data: 9752 / 10000
# Epoch 33 training complete in 34.53
# Accuracy on evaluation data: 9755 / 10000
# Epoch 34 training complete in 34.33
# Accuracy on evaluation data: 9761 / 10000
# Epoch 35 training complete in 34.48
# Accuracy on evaluation data: 9757 / 10000
# Epoch 36 training complete in 34.36
# Accuracy on evaluation data: 9760 / 10000
# Epoch 37 training complete in 34.50
# Accuracy on evaluation data: 9756 / 10000
# Epoch 38 training complete in 34.51
# Accuracy on evaluation data: 9761 / 10000
# Epoch 39 training complete in 34.63
# Accuracy on evaluation data: 9777 / 10000
# Epoch 40 training complete in 34.58
# Accuracy on evaluation data: 9779 / 10000
# Epoch 41 training complete in 34.62
# Accuracy on evaluation data: 9770 / 10000
# Epoch 42 training complete in 34.57
# Accuracy on evaluation data: 9780 / 10000
# Epoch 43 training complete in 34.60
# Accuracy on evaluation data: 9757 / 10000
# Epoch 44 training complete in 34.55
# Accuracy on evaluation data: 9765 / 10000
# Epoch 45 training complete in 34.43
# Accuracy on evaluation data: 9785 / 10000
# Epoch 46 training complete in 34.42
# Accuracy on evaluation data: 9780 / 10000
# Epoch 47 training complete in 34.67
# Accuracy on evaluation data: 9774 / 10000
# Epoch 48 training complete in 34.73
# Accuracy on evaluation data: 9763 / 10000
# Epoch 49 training complete in 34.56
# Accuracy on evaluation data: 9783 / 10000
# Epoch 50 training complete in 34.77
# Accuracy on evaluation data: 9777 / 10000
# Epoch 51 training complete in 34.46
# Accuracy on evaluation data: 9796 / 10000
# Epoch 52 training complete in 34.47
# Accuracy on evaluation data: 9790 / 10000
# Epoch 53 training complete in 34.54
# Accuracy on evaluation data: 9780 / 10000
# Epoch 54 training complete in 34.56
# Accuracy on evaluation data: 9781 / 10000
# Epoch 55 training complete in 34.64
# Accuracy on evaluation data: 9780 / 10000
# Epoch 56 training complete in 34.66
# Accuracy on evaluation data: 9783 / 10000
# Epoch 57 training complete in 34.48
# Accuracy on evaluation data: 9793 / 10000
# Epoch 58 training complete in 34.56
# Accuracy on evaluation data: 9776 / 10000
# Epoch 59 training complete in 34.53
# Accuracy on evaluation data: 9775 / 10000
# Total training time: 2085.83
# ([],
#  [9015,
#   9214,
#   9358,
#   9420,
#   9447,
#   9485,
#   9543,
#   9556,
#   9581,
#   9591,
#   9619,
#   9637,
#   9631,
#   9642,
#   9655,
#   9675,
#   9682,
#   9686,
#   9686,
#   9703,
#   9687,
#   9722,
#   9719,
#   9706,
#   9727,
#   9740,
#   9730,
#   9748,
#   9737,
#   9740,
#   9746,
#   9761,
#   9752,
#   9755,
#   9761,
#   9757,
#   9760,
#   9756,
#   9761,
#   9777,
#   9779,
#   9770,
#   9780,
#   9757,
#   9765,
#   9785,
#   9780,
#   9774,
#   9763,
#   9783,
#   9777,
#   9796,
#   9790,
#   9780,
#   9781,
#   9780,
#   9783,
#   9793,
#   9776,
#   9775],
#  [],
#  [],
#  [35.50922465324402,
#   35.74444580078125,
#   35.73492097854614,
#   35.321563959121704,
#   35.73364758491516,
#   36.02116823196411,
#   35.8905553817749,
#   35.066542863845825,
#   34.986703395843506,
#   35.2240731716156,
#   35.02387547492981,
#   34.86492300033569,
#   34.789984464645386,
#   34.88617920875549,
#   34.752753257751465,
#   34.559542417526245,
#   34.60291290283203,
#   34.71967077255249,
#   34.69897103309631,
#   34.524953842163086,
#   34.59480357170105,
#   34.51610350608826,
#   34.839929819107056,
#   34.70566415786743,
#   34.73787450790405,
#   34.89754581451416,
#   34.6075975894928,
#   34.69170117378235,
#   34.55479717254639,
#   34.45872759819031,
#   34.58679151535034,
#   34.72495102882385,
#   34.51482892036438,
#   34.532761096954346,
#   34.32807230949402,
#   34.480085134506226,
#   34.36181640625,
#   34.503050804138184,
#   34.51337480545044,
#   34.62550330162048,
#   34.58286690711975,
#   34.61876654624939,
#   34.57233810424805,
#   34.60394310951233,
#   34.54527497291565,
#   34.42727756500244,
#   34.42000985145569,
#   34.668044328689575,
#   34.73319125175476,
#   34.55862355232239,
#   34.76645088195801,
#   34.46103835105896,
#   34.46805453300476,
#   34.542070150375366,
#   34.55892896652222,
#   34.63624572753906,
#   34.66099834442139,
#   34.48037886619568,
#   34.56368398666382,
#   34.52609062194824],
#  2085.826869249344)

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")

import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)

import network2
net=network2.Network([784,100,100,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in 47.03
# Accuracy on evaluation data: 8833 / 10000
# Epoch 1 training complete in 46.99
# Accuracy on evaluation data: 9195 / 10000
# Epoch 2 training complete in 46.82
# Accuracy on evaluation data: 9326 / 10000
# Epoch 3 training complete in 47.20
# Accuracy on evaluation data: 9407 / 10000
# Epoch 4 training complete in 47.21
# Accuracy on evaluation data: 9483 / 10000
# Epoch 5 training complete in 47.41
# Accuracy on evaluation data: 9500 / 10000
# Epoch 6 training complete in 47.27
# Accuracy on evaluation data: 9556 / 10000
# Epoch 7 training complete in 47.28
# Accuracy on evaluation data: 9581 / 10000
# Epoch 8 training complete in 47.23
# Accuracy on evaluation data: 9613 / 10000
# Epoch 9 training complete in 47.55
# Accuracy on evaluation data: 9621 / 10000
# Epoch 10 training complete in 47.72
# Accuracy on evaluation data: 9637 / 10000
# Epoch 11 training complete in 47.30
# Accuracy on evaluation data: 9639 / 10000
# Epoch 12 training complete in 47.07
# Accuracy on evaluation data: 9644 / 10000
# Epoch 13 training complete in 47.13
# Accuracy on evaluation data: 9679 / 10000
# Epoch 14 training complete in 46.93
# Accuracy on evaluation data: 9695 / 10000
# Epoch 15 training complete in 47.44
# Accuracy on evaluation data: 9684 / 10000
# Epoch 16 training complete in 47.56
# Accuracy on evaluation data: 9702 / 10000
# Epoch 17 training complete in 48.00
# Accuracy on evaluation data: 9685 / 10000
# Epoch 18 training complete in 47.31
# Accuracy on evaluation data: 9705 / 10000
# Epoch 19 training complete in 47.30
# Accuracy on evaluation data: 9682 / 10000
# Epoch 20 training complete in 47.42
# Accuracy on evaluation data: 9730 / 10000
# Epoch 21 training complete in 47.48
# Accuracy on evaluation data: 9685 / 10000
# Epoch 22 training complete in 47.33
# Accuracy on evaluation data: 9726 / 10000
# Epoch 23 training complete in 47.53
# Accuracy on evaluation data: 9720 / 10000
# Epoch 24 training complete in 47.57
# Accuracy on evaluation data: 9720 / 10000
# Epoch 25 training complete in 47.44
# Accuracy on evaluation data: 9721 / 10000
# Epoch 26 training complete in 47.52
# Accuracy on evaluation data: 9728 / 10000
# Epoch 27 training complete in 47.42
# Accuracy on evaluation data: 9719 / 10000
# Epoch 28 training complete in 47.19
# Accuracy on evaluation data: 9737 / 10000
# Epoch 29 training complete in 47.22
# Accuracy on evaluation data: 9743 / 10000
# Epoch 30 training complete in 47.06
# Accuracy on evaluation data: 9742 / 10000
# Epoch 31 training complete in 47.23
# Accuracy on evaluation data: 9726 / 10000
# Epoch 32 training complete in 46.89
# Accuracy on evaluation data: 9772 / 10000
# Epoch 33 training complete in 46.57
# Accuracy on evaluation data: 9757 / 10000
# Epoch 34 training complete in 46.57
# Accuracy on evaluation data: 9758 / 10000
# Epoch 35 training complete in 46.59
# Accuracy on evaluation data: 9768 / 10000
# Epoch 36 training complete in 46.47
# Accuracy on evaluation data: 9764 / 10000
# Epoch 37 training complete in 46.64
# Accuracy on evaluation data: 9752 / 10000
# Epoch 38 training complete in 46.49
# Accuracy on evaluation data: 9755 / 10000
# Epoch 39 training complete in 46.78
# Accuracy on evaluation data: 9744 / 10000
# Epoch 40 training complete in 46.61
# Accuracy on evaluation data: 9761 / 10000
# Epoch 41 training complete in 46.63
# Accuracy on evaluation data: 9763 / 10000
# Epoch 42 training complete in 46.35
# Accuracy on evaluation data: 9789 / 10000
# Epoch 43 training complete in 46.56
# Accuracy on evaluation data: 9739 / 10000
# Epoch 44 training complete in 46.47
# Accuracy on evaluation data: 9778 / 10000
# Epoch 45 training complete in 46.57
# Accuracy on evaluation data: 9777 / 10000
# Epoch 46 training complete in 46.45
# Accuracy on evaluation data: 9686 / 10000
# Epoch 47 training complete in 46.73
# Accuracy on evaluation data: 9775 / 10000
# Epoch 48 training complete in 46.39
# Accuracy on evaluation data: 9790 / 10000
# Epoch 49 training complete in 46.57
# Accuracy on evaluation data: 9756 / 10000
# Epoch 50 training complete in 46.55
# Accuracy on evaluation data: 9779 / 10000
# Epoch 51 training complete in 46.51
# Accuracy on evaluation data: 9731 / 10000
# Epoch 52 training complete in 46.31
# Accuracy on evaluation data: 9785 / 10000
# Epoch 53 training complete in 46.56
# Accuracy on evaluation data: 9779 / 10000
# Epoch 54 training complete in 46.49
# Accuracy on evaluation data: 9756 / 10000
# Epoch 55 training complete in 46.49
# Accuracy on evaluation data: 9785 / 10000
# Epoch 56 training complete in 46.42
# Accuracy on evaluation data: 9800 / 10000
# Epoch 57 training complete in 46.71
# Accuracy on evaluation data: 9789 / 10000
# Epoch 58 training complete in 46.72
# Accuracy on evaluation data: 9786 / 10000
# Epoch 59 training complete in 46.50
# Accuracy on evaluation data: 9791 / 10000
# Total training time: 2817.73
# ([],
#  [8833,
#   9195,
#   9326,
#   9407,
#   9483,
#   9500,
#   9556,
#   9581,
#   9613,
#   9621,
#   9637,
#   9639,
#   9644,
#   9679,
#   9695,
#   9684,
#   9702,
#   9685,
#   9705,
#   9682,
#   9730,
#   9685,
#   9726,
#   9720,
#   9720,
#   9721,
#   9728,
#   9719,
#   9737,
#   9743,
#   9742,
#   9726,
#   9772,
#   9757,
#   9758,
#   9768,
#   9764,
#   9752,
#   9755,
#   9744,
#   9761,
#   9763,
#   9789,
#   9739,
#   9778,
#   9777,
#   9686,
#   9775,
#   9790,
#   9756,
#   9779,
#   9731,
#   9785,
#   9779,
#   9756,
#   9785,
#   9800,
#   9789,
#   9786,
#   9791],
#  [],
#  [],
#  [47.034324169158936,
#   46.99093699455261,
#   46.81745958328247,
#   47.19773077964783,
#   47.20812487602234,
#   47.40619683265686,
#   47.27175831794739,
#   47.2754602432251,
#   47.23225378990173,
#   47.54549980163574,
#   47.715252161026,
#   47.30349922180176,
#   47.066359519958496,
#   47.12787580490112,
#   46.9251983165741,
#   47.43720269203186,
#   47.5618851184845,
#   48.003570556640625,
#   47.31132197380066,
#   47.299132347106934,
#   47.42056703567505,
#   47.476412534713745,
#   47.32718801498413,
#   47.53369498252869,
#   47.56606912612915,
#   47.43659782409668,
#   47.51519823074341,
#   47.41658592224121,
#   47.18710017204285,
#   47.2179536819458,
#   47.060163736343384,
#   47.22769284248352,
#   46.889514446258545,
#   46.57377910614014,
#   46.57080316543579,
#   46.58850932121277,
#   46.472304582595825,
#   46.644583225250244,
#   46.492892265319824,
#   46.78146195411682,
#   46.61185312271118,
#   46.632739782333374,
#   46.34928297996521,
#   46.55807638168335,
#   46.47130608558655,
#   46.57493567466736,
#   46.450517416000366,
#   46.727086305618286,
#   46.38917326927185,
#   46.57146620750427,
#   46.54570651054382,
#   46.513922452926636,
#   46.3139214515686,
#   46.56282019615173,
#   46.485466718673706,
#   46.49472165107727,
#   46.417659521102905,
#   46.70842885971069,
#   46.72228407859802,
#   46.50240659713745],
#  2817.7338905334473)
